# %% [markdown]
# # Analyzing the Used Car Price

# %% [markdown]
# ## Introduction

# %% [markdown]
# * This dataset creat for price prediction of used car with high accuracy.This dataset containing with  various car features like model,km_driven,fuel type history. Our motive to analysis this data for creat a relationship between the cars features and selling price which helps to become demandable among the buyers, sellers and stockholders.

# %% [markdown]
# ##### Problem Statement

# %% [markdown]
# * We have sample data listing, through the analysis find out the best car with their feature which helps to increase the demand in the market and also find out  poor feature of cars we can also work on that.Based on a given test data depending on any column or not and if depending then which columns are more responsible for that.

# %% [markdown]
# ## Source of Dataset

# %% [markdown]
# * We collected the dataset from Kaggle.com

# %% [markdown]
# ## Size of Dataset

# %% [markdown]
# * Size of Titanic dataset is 4KB

# %% [markdown]
# ## About the Dataset

# %% [markdown]
# * Used Car Price Dataset contains a sample of data giving an overview of the features of various car models and their history.
# * Dataset contains 09 columns namely -Car_Name,Year,Selling_Price,Present_Price,Kms_Driven, Fuel_Type,Seller_Type,
#                                       Transmission,Owner

# %% [markdown]
# ## Libraries Used
# * Numpy
# * Pandas
# * Matplotlib
# * Seaborn

# %% [markdown]
# ## Categories
# * In this dataset, we have both categorical and non-categorical features.
# * Categorical Columns

# %% [markdown]
# ## Overview of the Features
# Here the mention cars history like cars name year selling price present price  km_driven wich help to know
# about which used cars are good condition for marketing purpose.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# # Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the dataset

# %%
df=pd.read_csv('cardekho_data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.shape
# Out:
# (301, 9)

# %%
df.sample(3)
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 299               city  2017          11.50           12.5        9000
# 103  Bajaj Dominar 400  2017           1.45            1.6        1200
# 218              verna  2014           6.45            9.4       45078
#
#     Fuel_Type Seller_Type Transmission  Owner
# 299    Diesel      Dealer       Manual      0
# 103    Petrol  Individual       Manual      0
# 218    Petrol      Dealer       Manual      0

# %% [markdown]
# ## Various features in Cardekho dataset

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# ## Type of each feature in dataset

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %% [markdown]
# #### Checking values of each column

# %%
df.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
df['Selling_Price'].unique()
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  3.25,  2.65,  4.9 ,
#         4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,  6.  ,  1.95,  3.1 ,  2.35,
#         4.95,  5.5 ,  2.95,  4.65,  0.35,  5.85,  2.55,  1.25,  1.05,
#         5.8 , 14.9 , 23.  , 18.  , 16.  ,  2.75,  3.6 ,  4.5 ,  4.1 ,
#        19.99,  6.95, 18.75, 23.5 , 33.  , 19.75,  4.35, 14.25,  3.95,
#         1.5 ,  5.25, 14.5 , 14.73, 12.5 ,  3.49, 35.  ,  5.9 ,  3.45,
#         3.8 , 11.25,  3.51,  4.  , 20.75, 17.  ,  7.05,  9.65,  1.75,
#         1.7 ,  1.65,  1.45,  1.35,  1.2 ,  1.15,  1.11,  1.1 ,  1.  ,
#         0.95,  0.9 ,  0.75,  0.8 ,  0.78,  0.72,  0.65,  0.6 ,  0.55,
#         0.52,  0.51,  0.5 ,  0.48,  0.45,  0.42,  0.4 ,  0.38,  0.31,
#         0.3 ,  0.27,  0.25,  0.2 ,  0.18,  0.17,  0.16,  0.15,  0.12,
#         0.1 ,  5.75,  5.15,  7.9 ,  4.85, 11.75,  3.15,  6.45,  3.5 ,
# ...

# %%
df['Present_Price'].unique()
# Out:
# array([ 5.59 ,  9.54 ,  9.85 ,  4.15 ,  6.87 ,  9.83 ,  8.12 ,  8.61 ,
#         8.89 ,  8.92 ,  3.6  , 10.38 ,  9.94 ,  7.71 ,  7.21 , 10.79 ,
#         5.09 ,  7.98 ,  3.95 ,  5.71 ,  8.01 ,  3.46 ,  4.41 ,  4.99 ,
#         5.87 ,  6.49 ,  5.98 ,  4.89 ,  7.49 ,  9.95 ,  8.06 ,  7.74 ,
#         7.2  ,  2.28 ,  3.76 ,  7.87 ,  3.98 ,  7.15 ,  2.69 , 12.04 ,
#         9.29 , 30.61 , 19.77 , 10.21 , 15.04 ,  7.27 , 18.54 ,  6.8  ,
#        35.96 , 18.61 ,  7.7  , 36.23 ,  6.95 , 23.15 , 20.45 , 13.74 ,
#        20.91 ,  6.76 , 12.48 ,  8.93 , 14.68 , 12.35 , 22.83 , 14.89 ,
#         7.85 , 25.39 , 13.46 , 23.73 , 92.6  ,  6.05 , 16.09 , 13.7  ,
#        22.78 , 18.64 ,  1.9  ,  1.82 ,  1.78 ,  1.6  ,  1.47 ,  2.37 ,
#         3.45 ,  1.5  ,  2.4  ,  1.4  ,  1.26 ,  1.17 ,  1.75 ,  0.95 ,
#         0.8  ,  0.87 ,  0.84 ,  0.82 ,  0.81 ,  0.74 ,  1.2  ,  0.787,
#         0.99 ,  0.94 ,  0.826,  0.55 ,  0.88 ,  0.51 ,  0.52 ,  0.54 ,
# ...

# %%
df['Kms_Driven'].unique()
# Out:
# array([ 27000,  43000,   6900,   5200,  42450,   2071,  18796,  33429,
#         20273,  42367,   2135,  51000,  15000,  26000,  77427,  41678,
#         35500,  41442,  25000,   2400,  50000,  45280,  56879,  20000,
#         55138,  16200,  44542,  45000,  51439,  54200,  39000,  49998,
#         48767, 127000,  10079,  62000,  24524,  46706,  58000,  45780,
#         64532,  65000,  25870,  37000, 104707,  40000, 135000,  90000,
#         70000,  40534,  39485,  41000,  40001,  40588,  78000,  47000,
#          6000,  11000,  59000,  88000,  12000,  71000,  56001,  83000,
#         36000,  72000, 135154,  80000,  89000,  23000,  38000, 197176,
#        142000,  56000,  58242,  75000,  29000,   8700,  50024,   3000,
#          1400,   4000,   1200,   4100,  21700,  16500,  18000,   7000,
#         35000,  17000,  17500,  33000,  14000,   5400,   5700,  46500,
#         11500,   1300,   5000,   3500,    500,  11800,  23500,  16000,
# ...

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %% [markdown]
# # Checking Missing values

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Car_Name         0.0
# Year             0.0
# Selling_Price    0.0
# Present_Price    0.0
# Kms_Driven       0.0
# Fuel_Type        0.0
# Seller_Type      0.0
# Transmission     0.0
# Owner            0.0
# dtype: float64

# %% [markdown]
# # Handling missing values and duplicates

# %% [markdown]
# ### Dropping the columns Cabin,ticket,name

# %%
df.drop(['Seller_Type','Owner'],axis=1,inplace=True)

# %% [markdown]
# * Dropped the columns that I did not need for the prediction.
# * I dropped columns Seller_Type','Owner'.

# %% [markdown]
# ### Dropping missing values row wise

# %%
df.dropna(axis=0,inplace=True)

# %% [markdown]
# ### checking duplicate values

# %%
df.duplicated().sum()
# Out:
# 2

# %%
duplicates = df[df.duplicated()]
print("Number of duplicate rows:", duplicates.shape[0])
print("Duplicate rows:\n", duplicates)
# Out:
# Number of duplicate rows: 2
# Duplicate rows:
#      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Transmission
# 17       Manual
# 93    Automatic

# %%
df = df.drop_duplicates()

# %%
df.to_csv('cleaned_dataset.csv', index=False)  # Replace 'cleaned_dataset.csv' with your desired output file name

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 299, dtype: bool>

# %% [markdown]
# ### Below are the Remaining columns after handling duplicated  values.

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Transmission'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # What about the difference between selling price and present price

# %%
df['Price_Difference']= df['Present_Price']-df['Selling_Price']

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Transmission  Price_Difference
# 0         Manual              2.24
# 1         Manual              4.79
# ...

# %%
sns.violinplot(x='Year',y='Price_Difference',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Price_Difference'>

# %% [markdown]
# * as per analysis we can find the price different maximum 20% at present price

# %% [markdown]
# # 2 What is co relation between selling price and present price?

# %%
df[['Selling_Price', 'Present_Price']].groupby(['Selling_Price'],as_index=False).mean().sort_values(by='Present_Price')
# Out:
#      Selling_Price  Present_Price
# 5             0.18       0.320000
# 8             0.27       0.470000
# 3             0.16       0.510000
# 4             0.17       0.520000
# 9             0.30       0.523333
# ..             ...            ...
# 148          18.75      35.960000
# 150          19.99      35.960000
# 153          23.50      35.960000
# 154          33.00      36.230000
# 155          35.00      92.600000
#
# [156 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Selling_Price',y= 'Present_Price',data=df)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Present_Price'>

# %% [markdown]
# * As per analysis Present Price also increse with Selling Price

# %% [markdown]
# ## 3What is the overall distribution of used car prices in the dataset?

# %%
df['Selling_Price'].describe()
# Out:
# count    299.000000
# mean       4.589632
# std        4.984240
# min        0.100000
# 25%        0.850000
# 50%        3.510000
# 75%        6.000000
# max       35.000000
# Name: Selling_Price, dtype: float64

# %%
df['Present_Price'].describe()
# Out:
# count    299.000000
# mean       7.541037
# std        8.567887
# min        0.320000
# 25%        1.200000
# 50%        6.100000
# 75%        9.840000
# max       92.600000
# Name: Present_Price, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Selling_Price'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Used Car Prices')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %% [markdown]
# * As per analysis  maximum car are selling between 5 lac and minimum price between 30 to 40 lac.

# %%
sns.boxplot(df['Selling_Price'])
# Out:
# <Axes: ylabel='Selling_Price'>

# %% [markdown]
# * as per  analysis we can find some outer

# %% [markdown]
# ## 4.Explore how factors fuel type correlate with the car prices.

# %%
df.groupby('Fuel_Type') ['Selling_Price'].mean()
# Out:
# Fuel_Type
# CNG        3.100000
# Diesel    10.102759
# Petrol     3.264184
# Name: Selling_Price, dtype: float64

# %%
sns.scatterplot(x='Fuel_Type', y='Selling_Price', data=df)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Selling_Price'>

# %% [markdown]
# * As per analysis  Diesel Fuel_Type cars are demandable for the selling purpose

# %%
df.groupby('Fuel_Type') ['Present_Price'].mean()
# Out:
# Fuel_Type
# CNG        6.415000
# Diesel    15.646034
# Petrol     5.583556
# Name: Present_Price, dtype: float64

# %%
sns.barplot(x= 'Fuel_Type',y='Selling_Price',data=df)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Selling_Price'>

# %% [markdown]
# * As per analysis Diesel Fuel_Type Car is deemanding on the marker for selling purpuse.

# %% [markdown]
# # 5 .Explore how factors mileage and fue correlate with the car prices.

# %%
df.groupby('Kms_Driven') ['Selling_Price'].mean()
# Out:
# Kms_Driven
# 500       0.585
# 1000      0.450
# 1200      1.450
# 1300      0.650
# 1400      1.700
#           ...
# 135154    1.500
# 142000    2.500
# 197176    3.490
# 213000    0.310
# 500000    0.170
# Name: Selling_Price, Length: 206, dtype: float64

# %%
sns.scatterplot(x='Kms_Driven', y = 'Selling_Price', data= df)
# Out:
# <Axes: xlabel='Kms_Driven', ylabel='Selling_Price'>

# %% [markdown]
# * As per analysis 100000 km_Driven cars are mostli demandable in the market

# %% [markdown]
# ## 6 Explore how factors like brand, model, year, mileage, and fuel type correlate with the car prices.

# %%
df[['Selling_Price','Kms_Driven','Present_Price']].corr()
# Out:
#                Selling_Price  Kms_Driven  Present_Price
# Selling_Price       1.000000    0.028566       0.876378
# Kms_Driven          0.028566    1.000000       0.205253
# Present_Price       0.876378    0.205253       1.000000

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='Year', y='Kms_Driven', data=df)
plt.title('Kms_Driven vs. Price')
# Out:
# Text(0.5, 1.0, 'Kms_Driven vs. Price')

# %% [markdown]
# * As per analysis 100000 Kms_Driven spped cars demand become increas towards to 2018 years.

# %%
df[['Selling_Price','Kms_Driven','Present_Price']].corr()
# Out:
#                Selling_Price  Kms_Driven  Present_Price
# Selling_Price       1.000000    0.028566       0.876378
# Kms_Driven          0.028566    1.000000       0.205253
# Present_Price       0.876378    0.205253       1.000000

# %%
sns.scatterplot(x = 'Kms_Driven',y= 'Year',data= df)
# Out:
# <Axes: xlabel='Kms_Driven', ylabel='Year'>

# %% [markdown]
# * As per analysis 100000 Kms_Driven spped cars demand become increas towards to 2012 year but in 2018 selling was going to be down .

# %% [markdown]
# ## 7Explore how factors like brand, model, year correlate with the car prices

# %%
df.groupby(['Car_Name','Year','Fuel_Type','Transmission']) ['Present_Price'].mean()
# Out:
# Car_Name       Year  Fuel_Type  Transmission
# 800            2003  Petrol     Manual          2.28
# Activa 3g      2008  Petrol     Automatic       0.52
#                2016  Petrol     Automatic       0.54
# Activa 4g      2017  Petrol     Automatic       0.51
# Bajaj  ct 100  2015  Petrol     Manual          0.32
#                                                 ...
# wagon r        2013  Petrol     Manual          4.41
#                2015  CNG        Manual          5.09
# xcent          2014  Petrol     Manual          7.13
#                2015  Petrol     Manual          7.13
#                2017  Petrol     Manual          7.13
# Name: Present_Price, Length: 233, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='Year',y='Transmission',hue='Fuel_Type',discrete='Present_Price',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Transmission'>

# %% [markdown]
# * As per analysis manual featuers and disel fuel type cars are become most demandable towords 2018 years

# %% [markdown]
# ## 9 Are there specific brands or models that command higher prices?

# %%
df1=df.groupby('Car_Name') ['Present_Price'].max()

# %%
df1
# Out:
# Car_Name
# 800                  2.28
# Activa 3g            0.54
# Activa 4g            0.51
# Bajaj  ct 100        0.32
# Bajaj Avenger 150    0.80
#                      ...
# sx4                  9.54
# verna                9.40
# vitara brezza        9.83
# wagon r              5.09
# xcent                7.13
# Name: Present_Price, Length: 98, dtype: float64

# %%
_=plt.figure(figsize=(10, 10))
_=plt.pie(df1, labels=df1.index, autopct='%1.1f%%', startangle=140)

# %% [markdown]
# * as per analysis land Cruiser model car price is very high among the car models.

# %% [markdown]
# ## 10 Are there specific brands or models that command low prices?

# %%
df2 =df.groupby('Car_Name') ['Selling_Price'].min()

# %%
car=df2.head(10)

# %%
car
# Out:
# Car_Name
# 800                         0.35
# Activa 3g                   0.17
# Activa 4g                   0.40
# Bajaj  ct 100               0.18
# Bajaj Avenger 150           0.75
# Bajaj Avenger 150 street    0.60
# Bajaj Avenger 220           0.72
# Bajaj Avenger 220 dtsi      0.45
# Bajaj Avenger Street 220    0.45
# Bajaj Discover 100          0.27
# Name: Selling_Price, dtype: float64

# %%
_=plt.figure(figsize=(10, 10))
_=plt.pie(car, labels=car.index, autopct='%1.1f%%', startangle=140)

# %% [markdown]
# * as per analysis Active 3g model car is selling price is low among the car

# %% [markdown]
# # As Per Data_Set Analysis Conclusion:
# * Used Car also demandable for the selling and purchasing purpose in the marker.
# * We find the it's given the profit atleast 2% compare the selling price.
# * So that we can resell the used car at a higher price instead of half price.
# * Present Price is also increase with the selling price maximum mount is 92.60000
#   and minimum price 0.320000
# * Diesel Fuel Type ,10000 Kms _driven speed,Manual Transmission features
#   car is trending in the market.
# * In this dataset we can find land cruiser model car is moslty selling till
#   the 2018 year 18.2%
# * Activa 3g during the first selling time demand is less at 3.9%
